# %%
import os

import numpy as np
import pandas as pd

from utils import *
from metrics import *

from basic_decision_functions import *
# from additional_decision_functions import *

# %% [markdown]
# ## Parameters

# %%
FIDELITY_METRIC = "L1"

## TODO: implement and customize.
DATA_FILE = "data.csv"

### Save predictions (good for large data samples)
SAVE = True

# %% [markdown]
# ## Data Details

# %%
## TODO: implement and customize.

INDEX_COL = "index"
PROB_COLS = [
    "bisg_bayes_nh_aian",
    "bisg_bayes_nh_api",
    "bisg_bayes_nh_black",
    "bisg_bayes_hispanic",
    "bisg_bayes_nh_white",
    "bisg_bayes_other",
]  # []
TRUE_LABEL_COL = "self_reported"  ## None if no true labels available
CONDITION_COLS = None ## None if joint discretizations should not be divided by condition

## include uncoded class as the last class
CLASS_NAMES = pd.Series(
    [
        "AIAN",
        "API",
        "Black",
        "Hispanic",
        "White",
        "Other",
        "Uncoded",
    ],
    name="Race",
)
UNCODED_VAL = len(CLASS_NAMES) - 1

## n_samples to truncate to if desired, useful for testing.
N_SAMPLES = 100000  ## default None is the whole dataset

# %% [markdown]
# ## Cleaning & Processing

# %%
## cleaning


## apply any intended cleaning
def get_and_clean_data(data_file: str, index_col: str | None = None, n_samples: int | None = None) -> pd.DataFrame:
    ## TODO: implement and customize.

    ## read file
    data = pd.read_csv(data_file, index_col=index_col)

    ## shuffle
    data = data.sample(frac=1)

    ## additional cleaning steps here
    # ...

    ## truncate
    if n_samples is not None:
        data = data.iloc[:n_samples]

    return data


cleaned = get_and_clean_data(DATA_FILE, index_col=INDEX_COL, n_samples=N_SAMPLES)

cleaned
# Out:
#          bisg_bayes_nh_aian  bisg_bayes_nh_api  bisg_bayes_nh_black  \
# index
# 1119327            0.004678           0.001675             0.055396
# 4046569            0.002596           0.007855             0.002535
# 2840519            0.003278           0.005653             0.516298
# 1833634            0.850864           0.000419             0.057370
# 3912009            0.022864           0.000696             0.015204
# ...                     ...                ...                  ...
# 1568755            0.004587           0.002221             0.153832
# 324944             0.002342           0.001420             0.674883
# 3315723            0.002377           0.019412             0.004419
# 926034             0.007935           0.000826             0.020107
# 3983475            0.008167           0.001686             0.001460
#
#          bisg_bayes_hispanic  bisg_bayes_nh_white  bisg_bayes_other  \
# index
# 1119327             0.004953             0.929344          0.003954
# 4046569             0.011803             0.972399          0.002812
# 2840519             0.017130             0.451139          0.006501
# 1833634             0.003195             0.086613          0.001539
# 3912009             0.003696             0.949364          0.008176
# ...                      ...                  ...               ...
# 1568755             0.011607             0.817416          0.010337
# 324944              0.006884             0.309529          0.004942
# 3315723             0.021690             0.948922          0.003180
# 926034              0.006027             0.959089          0.006016
# 3983475             0.006688             0.979649          0.002351
#
#          self_reported     county
# index
# 1119327              4  cleveland
# 4046569              4   cabarrus
# 2840519              2     durham
# 1833634              0    robeson
# 3912009              4   cherokee
# ...                ...        ...
# 1568755              4   buncombe
# 324944               2       pitt
# 3315723              4   davidson
# 926034               4    haywood
# 3983475              4   davidson
#
# [100000 rows x 8 columns]

# %%
# CLEAN DATA
labels = cleaned[TRUE_LABEL_COL] if TRUE_LABEL_COL is not None else None
probs = cleaned[PROB_COLS]
n_prob_classes = len(PROB_COLS)

# %% [markdown]
# ## Discretizations

# %%
## directory to save outputs to
cond_text = (
    "unconditional"
    if CONDITION_COLS is None
    else f"{'-'.join(CONDITION_COLS)}_conditional"
)

predictions_dir = f"predictions/{cond_text}/"
if SAVE:
    os.makedirs(predictions_dir, exist_ok=True)

# %%
## DISCRETIZATION PARAMETERS
USE_METHODS = {
    "Argmax",
    "Thompson Sampling",
    "Aggregate Posterior Matching",
    "Threshold",
    "Data-Driven Threshold",
    # "Integer Program",  ## NOTE: COMMENTED OUT BY DEFAULT. WILL ONLY WORK WITH GUROBI LICENSE OR OTHER INTEGER PROGRAM SOLVER INSTALLED.
    "Top-k Sampling",
    "True Population Matching",
}

#### METHOD PARAMETERS
## integer program gamma values
IP_GAMMAS = np.round(np.linspace(0.8, 0.99, 20, endpoint=True), 2)
## threshold parameter values
PARTIAL_THRESHOLDS = np.round(np.linspace(0.5, 1, 11, endpoint=True), 2)
## k values for top_k sampling
TOP_KS = np.arange(2, len(PROB_COLS))

#### BATCHING PARAMETERS
## batching & calculations
BATCH_SIZE = 10000
N_PROCESSES = 0  ## default is a heuristic for what's fastest; 1 is not multiprocessed.
REMAINDER = False  ## By default, splits batches for joint decision-making into (approximately) evenly sized batches as close to the batch size as possible. If True, calculates as exact sizes, with a single batch of the remaining data pionts.

# %%
## INDIVIDUAL DISCRETIZATIONS
predictions = pd.DataFrame(index=probs.index)

if TRUE_LABEL_COL is not None:
    predictions[TRUE_LABEL_COL] = labels
predictions.columns.name = "Method"

if "Argmax" in USE_METHODS:
    predictions["Argmax"] = argmax_discretization(probs)

if "Thompson Sampling" in USE_METHODS:
    predictions["Thompson Sampling"] = thompson_discretization(probs)

# PARTIAL THRESHOLDS
if "Threshold" in USE_METHODS:
    thresholded_preds = pd.DataFrame(
        {
            f"Threshold at {threshold}": partial_threshold_discretization(
                probs, threshold, uncoded_val=UNCODED_VAL
            )
            for threshold in PARTIAL_THRESHOLDS
        },
        index=probs.index,
    )
    predictions = predictions.join([thresholded_preds], validate="one_to_one")

# TOP-K SAMPLES
if "Top-k Sampling" in USE_METHODS:
    top_k_preds = pd.DataFrame(
        {
            f"Top-{k} Sampling": top_k_discretization(probs, top_k=k)
            for k in TOP_KS
        },
        index=probs.index,
    )
    predictions = predictions.join([top_k_preds], validate="one_to_one")
# Out:
# Warning: having thresholds at <= 0.5 may lead to ties. If muliple classes are over the threshold, the class furthest over the threshold will be selected. If multiple classes are equally over the threshold, ties are broken in class order.

# %%
## JOINT DISCRETIZATIONS

batches, true_marginal_references = conditional_batching(
    cleaned,
    BATCH_SIZE,
    PROB_COLS,
    condition_columns=CONDITION_COLS,
    true_label_col=TRUE_LABEL_COL,
    remainder=REMAINDER,
)
batched_index = pd.concat(batches, axis="index").index  ## groupby will change row order

if "Aggregate Posterior Matching" in USE_METHODS:
    ap_matching = batched_matching_discretization(
        batches, reference_dists=None, n_processes=N_PROCESSES
    )
    ap_matching = pd.Series(
        ap_matching, index=batched_index, name="Aggregate Posterior Matching"
    )
    predictions = predictions.join([ap_matching], validate="one_to_one")

if "True Population Matching" in USE_METHODS:
    tm_matching = batched_matching_discretization(
        batches, reference_dists=true_marginal_references, n_processes=N_PROCESSES
    )
    tm_matching = pd.Series(
        tm_matching, index=batched_index, name="True Population Matching"
    )
    predictions = predictions.join([tm_matching], validate="one_to_one")

# NOTE: defaults to aggregate posterior. Easily modified to use true marginals for reference.
if "Integer Program" in USE_METHODS:
    ## output is shape (n_gammas, n_samples)
    raw_ips = batched_integer_program_discretization(
        batches,
        IP_GAMMAS,
        reference_dists=None,
        fidelity_metric=FIDELITY_METRIC,
        n_processes=N_PROCESSES,
    )
    ip_preds = pd.DataFrame(
        {
            f"Integer Program, $\gamma = {gamma}$": ip_pred
            for gamma, ip_pred in zip(IP_GAMMAS, raw_ips)
        },
        index=batched_index,
    )
    predictions = predictions.join([ip_preds], validate="one_to_one")
# Out:
# conditional value all
# condition size 100000
# /Users/edong/Documents/code/research/posterior_discretization/posterior_discretization/final_code/general/.venv/lib/python3.11/site-packages/numpy/_core/fromnumeric.py:57: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
# output class distribution [ 173  190 2076  373 7137   51]
# output class distribution [ 174  173 2089  370 7143   51]
# output class distribution [ 161  171 2080  370 7167   51]
# output class distribution [ 186  202 2057  372 7132   51]
# output class distribution [ 173  182 2092  368 7134   51]
# output class distribution [ 180  203 2095  359 7112   51]
# output class distribution [ 169  192 2104  380 7104   51]
# output class distribution [ 170  193 2098  374 7113   52]
# output class distribution [ 160  178 2098  400 7113   51]
# output class distribution [ 170  184 2114  378 7102   52]
# output class distribution [  88  101 2170  237 7252  152]
# output class distribution [  88  101 2170  237 7252  152]
# output class distribution [  88  101 2170  237 7252  152]
# output class distribution [  88  101 2170  237 7252  152]
# output class distribution [  88  101 2170  237 7252  152]
# output class distribution [  88  101 2170  237 7252  152]
# output class distribution [  88  101 2170  237 7252  152]
# output class distribution [  88  101 2170  237 7252  152]
# output class distribution [  88  101 2170  237 7252  152]
# output class distribution [  88  101 2170  237 7252  152]

# %%
## SVM approximation

training_batch = batch_dataset(probs, BATCH_SIZE)[0]
training_size = training_batch.shape[0]

## original method and data-driven approximation
method_names = ["Aggregate Posterior Matching"] + [
    f"Integer Program, $\gamma = {gamma}$" for gamma in IP_GAMMAS
]
approx_names = ["Data-Driven Threshold"] + [
    f"Data-Driven Threshold, $\gamma = {gamma}$" for gamma in IP_GAMMAS
]

if "Data-Driven Threshold" in USE_METHODS:
    for method, approx in zip(method_names, approx_names):
        if method in predictions:
            (
                X_train,
                y_train,
            ) = (
                probs.iloc[:training_size],
                predictions[method].iloc[:training_size],
            )
            X_test, y_test = probs, predictions[method]
            predictions[approx] = data_driven_threshold_discretization(
                X_train, y_train, X_test, testing_labels=y_test
            )
# Out:
# training accuracy 0.987
# testing accuracy 0.98618
# /Users/edong/Documents/code/research/posterior_discretization/posterior_discretization/final_code/general/.venv/lib/python3.11/site-packages/numpy/_core/fromnumeric.py:57: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)

# %%
# useful to save outputs when run on large datasets
if SAVE:
    predictions.to_csv(f"{predictions_dir}predictions.csv")

# %% [markdown]
# ## Assessment

# %% [markdown]
# ### Calculation

# %%
## load data predictions
if SAVE:
    predictions = pd.read_csv(
        f"{predictions_dir}predictions.csv",
        index_col=INDEX_COL if INDEX_COL is not None else ["Unnamed: 0"],
    )
    predictions.columns.name = "Method"
predictions
# Out:
# Method   self_reported  Argmax  Thompson Sampling  Threshold at 0.5  \
# index
# 1119327              4       4                  4                 4
# 4046569              4       4                  4                 4
# 2840519              2       2                  2                 2
# 1833634              0       0                  0                 0
# 3912009              4       4                  4                 4
# ...                ...     ...                ...               ...
# 1568755              4       4                  4                 4
# 324944               2       2                  2                 2
# 3315723              4       4                  1                 4
# 926034               4       4                  4                 4
# 3983475              4       4                  4                 4
#
# Method   Threshold at 0.55  Threshold at 0.6  Threshold at 0.65  \
# index
# 1119327                  4                 4                  4
# 4046569                  4                 4                  4
# 2840519                  6                 6                  6
# 1833634                  0                 0                  0
# 3912009                  4                 4                  4
# ...                    ...               ...                ...
# 1568755                  4                 4                  4
# 324944                   2                 2                  2
# 3315723                  4                 4                  4
# 926034                   4                 4                  4
# 3983475                  4                 4                  4
#
# Method   Threshold at 0.7  Threshold at 0.75  Threshold at 0.8  ...  \
# index                                                           ...
# 1119327                 4                  4                 4  ...
# 4046569                 4                  4                 4  ...
# 2840519                 6                  6                 6  ...
# 1833634                 0                  0                 0  ...
# 3912009                 4                  4                 4  ...
# ...                   ...                ...               ...  ...
# 1568755                 4                  4                 4  ...
# 324944                  6                  6                 6  ...
# 3315723                 4                  4                 4  ...
# 926034                  4                  4                 4  ...
# 3983475                 4                  4                 4  ...
#
# Method   Threshold at 0.9  Threshold at 0.95  Threshold at 1.0  \
# index
# 1119327                 4                  6                 6
# 4046569                 4                  4                 6
# 2840519                 6                  6                 6
# 1833634                 6                  6                 6
# 3912009                 4                  6                 6
# ...                   ...                ...               ...
# 1568755                 6                  6                 6
# 324944                  6                  6                 6
# 3315723                 4                  6                 6
# 926034                  4                  4                 6
# 3983475                 4                  4                 6
#
# Method   Top-2 Sampling  Top-3 Sampling  Top-4 Sampling  Top-5 Sampling  \
# index
# 1119327               4               4               4               4
# 4046569               4               4               4               4
# 2840519               2               4               2               4
# 1833634               0               4               0               0
# 3912009               4               4               4               4
# ...                 ...             ...             ...             ...
# 1568755               4               4               4               4
# 324944                2               2               2               2
# 3315723               4               4               4               4
# 926034                4               4               4               4
# 3983475               4               4               4               4
#
# Method   Aggregate Posterior Matching  True Population Matching  \
# index
# 1119327                             4                         4
# 4046569                             4                         4
# 2840519                             2                         2
# 1833634                             0                         0
# 3912009                             4                         4
# ...                               ...                       ...
# 1568755                             4                         4
# 324944                              2                         2
# 3315723                             4                         4
# 926034                              4                         4
# 3983475                             4                         4
#
# Method   Data-Driven Threshold
# index
# 1119327                      4
# 4046569                      4
# 2840519                      2
# 1833634                      0
# 3912009                      4
# ...                        ...
# 1568755                      4
# 324944                       2
# 3315723                      4
# 926034                       4
# 3983475                      4
#
# [100000 rows x 21 columns]

# %% [markdown]
# #### Accuracy and Fidelity

# %%
means = assess_predictions(
    predictions,
    probs=probs,
    true_labels=predictions[TRUE_LABEL_COL] if TRUE_LABEL_COL is not None else None,
    prior=None,
    fidelity_metric=FIDELITY_METRIC,
    uncoded_val=UNCODED_VAL,
)
means.index.name = "Method"
means
# Out:
#                               Dropped Fraction  Expected Accuracy  \
# Method
# self_reported                          0.00000           0.691969
# Argmax                                 0.00000           0.785477
# Thompson Sampling                      0.00000           0.698819
# Threshold at 0.5                       0.03391           0.796359
# Threshold at 0.55                      0.10918           0.819344
# Threshold at 0.6                       0.18323           0.841534
# Threshold at 0.65                      0.25230           0.861532
# Threshold at 0.7                       0.32260           0.880919
# Threshold at 0.75                      0.39621           0.899932
# Threshold at 0.8                       0.46965           0.917304
# Threshold at 0.85                      0.55477           0.934798
# Threshold at 0.9                       0.65777           0.952381
# Threshold at 0.95                      0.80765           0.972022
# Threshold at 1.0                       0.99990           1.000000
# Top-2 Sampling                         0.00000           0.719492
# Top-3 Sampling                         0.00000           0.709911
# Top-4 Sampling                         0.00000           0.703008
# Top-5 Sampling                         0.00000           0.698410
# Aggregate Posterior Matching           0.00000           0.765645
# True Population Matching               0.00000           0.767436
# Data-Driven Threshold                  0.00000           0.770359
#
#                               Aggregate Posterior Fidelity  Accuracy  \
# Method
# self_reported                                    -0.061246  1.000000
# Argmax                                           -0.213270  0.773480
# Thompson Sampling                                -0.002144  0.694290
# Threshold at 0.5                                 -0.239271  0.784575
# Threshold at 0.55                                -0.282423  0.807784
# Threshold at 0.6                                 -0.323617  0.829230
# Threshold at 0.65                                -0.349947  0.848455
# Threshold at 0.7                                 -0.370983  0.867449
# Threshold at 0.75                                -0.390892  0.886931
# Threshold at 0.8                                 -0.399986  0.905308
# Threshold at 0.85                                -0.408090  0.922422
# Threshold at 0.9                                 -0.436078  0.940888
# Threshold at 0.95                                -0.488707  0.963296
# Threshold at 1.0                                 -0.574850  1.000000
# Top-2 Sampling                                   -0.051894  0.712570
# Top-3 Sampling                                   -0.029694  0.702690
# Top-4 Sampling                                   -0.011066  0.694840
# Top-5 Sampling                                   -0.005282  0.692540
# Aggregate Posterior Matching                     -0.000056  0.750690
# True Population Matching                         -0.061326  0.759080
# Data-Driven Threshold                            -0.022294  0.756030
#
#                               Ground Truth Fidelity
# Method
# self_reported                             -0.000000
# Argmax                                    -0.208880
# Thompson Sampling                         -0.062680
# Threshold at 0.5                          -0.228233
# Threshold at 0.55                         -0.276252
# Threshold at 0.6                          -0.323317
# Threshold at 0.65                         -0.356107
# Threshold at 0.7                          -0.383073
# Threshold at 0.75                         -0.406815
# Threshold at 0.8                          -0.419402
# Threshold at 0.85                         -0.427506
# Threshold at 0.9                          -0.433768
# Threshold at 0.95                         -0.484638
# Threshold at 1.0                          -0.549680
# Top-2 Sampling                            -0.037440
# Top-3 Sampling                            -0.042120
# Top-4 Sampling                            -0.055960
# Top-5 Sampling                            -0.059140
# Aggregate Posterior Matching              -0.061280
# True Population Matching                  -0.000200
# Data-Driven Threshold                     -0.047300

# %% [markdown]
# #### Bias

# %%
## Class Counts
population_counts = preds_to_counts(predictions, class_map=CLASS_NAMES)
aggregate_posterior = list(np.sum(probs, axis=0)) + [0]
population_counts["Aggregate Posterior"] = aggregate_posterior
population_counts
# Out:
# Method    self_reported  Argmax  Thompson Sampling  Threshold at 0.5  \
# Race
# AIAN                882    1244               1723               824
# API                1008    1271               1910              1202
# Black             21704   12776              20827             11436
# Hispanic           2374    2788               3765              2748
# White             72516   81921              71293             80399
# Other              1516       0                482                 0
# Uncoded               0       0                  0              3391
#
# Method    Threshold at 0.55  Threshold at 0.6  Threshold at 0.65  \
# Race
# AIAN                    633               507                463
# API                    1156              1110               1096
# Black                  8533              5975               4245
# Hispanic               2703              2668               2604
# White                 76057             71417              66362
# Other                     0                 0                  0
# Uncoded               10918             18323              25230
#
# Method    Threshold at 0.7  Threshold at 0.75  Threshold at 0.8  ...  \
# Race                                                             ...
# AIAN                   425                390               374  ...
# API                   1042               1023               993  ...
# Black                 2927               1881              1287  ...
# Hispanic              2511               2365              2135  ...
# White                60835              54720             48246  ...
# Other                    0                  0                 0  ...
# Uncoded              32260              39621             46965  ...
#
# Method    Threshold at 0.95  Threshold at 1.0  Top-2 Sampling  Top-3 Sampling  \
# Race
# AIAN                    207                 0            1187            1328
# API                     700                 0            1346            1509
# Black                   200                 0           21348           21087
# Hispanic                 62                 0            2712            3491
# White                 18066                10           73407           72558
# Other                     0                 0               0              27
# Uncoded               80765             99990               0               0
#
# Method    Top-4 Sampling  Top-5 Sampling  Aggregate Posterior Matching  \
# Race
# AIAN                1517            1558                          1716
# API                 1802            1821                          1868
# Black              21056           20868                         20903
# Hispanic            3743            3842                          3744
# White              71657           71422                         71257
# Other                225             489                           512
# Uncoded                0               0                             0
#
# Method    True Population Matching  Data-Driven Threshold  Aggregate Posterior
# Race
# AIAN                           880                   1736          1714.985851
# API                           1010                   1737          1868.929479
# Black                        21700                  21618         20902.819174
# Hispanic                      2370                   3156          3742.400659
# White                        72520                  71636         71257.476567
# Other                         1520                    117           513.388270
# Uncoded                          0                      0             0.000000
#
# [7 rows x 22 columns]

# %%
## the class makeup of the output predictions
labeled_frac = np.sum(population_counts, axis=0) - population_counts.loc[CLASS_NAMES[UNCODED_VAL]]
population_fraction_table = population_counts / np.array(labeled_frac)[np.newaxis, :]
population_fraction_table
# Out:
# Method    self_reported   Argmax  Thompson Sampling  Threshold at 0.5  \
# Race
# AIAN            0.00882  0.01244            0.01723          0.008529
# API             0.01008  0.01271            0.01910          0.012442
# Black           0.21704  0.12776            0.20827          0.118374
# Hispanic        0.02374  0.02788            0.03765          0.028445
# White           0.72516  0.81921            0.71293          0.832210
# Other           0.01516  0.00000            0.00482          0.000000
# Uncoded         0.00000  0.00000            0.00000          0.035100
#
# Method    Threshold at 0.55  Threshold at 0.6  Threshold at 0.65  \
# Race
# AIAN               0.007106          0.006207           0.006192
# API                0.012977          0.013590           0.014658
# Black              0.095788          0.073154           0.056774
# Hispanic           0.030343          0.032665           0.034827
# White              0.853786          0.874383           0.887548
# Other              0.000000          0.000000           0.000000
# Uncoded            0.122561          0.224335           0.337435
#
# Method    Threshold at 0.7  Threshold at 0.75  Threshold at 0.8  ...  \
# Race                                                             ...
# AIAN              0.006274           0.006459          0.007052  ...
# API               0.015382           0.016943          0.018723  ...
# Black             0.043209           0.031153          0.024267  ...
# Hispanic          0.037068           0.039169          0.040256  ...
# White             0.898066           0.906275          0.909701  ...
# Other             0.000000           0.000000          0.000000  ...
# Uncoded           0.476233           0.656205          0.885547  ...
#
# Method    Threshold at 0.95  Threshold at 1.0  Top-2 Sampling  Top-3 Sampling  \
# Race
# AIAN               0.010762               0.0         0.01187         0.01328
# API                0.036392               0.0         0.01346         0.01509
# Black              0.010398               0.0         0.21348         0.21087
# Hispanic           0.003223               0.0         0.02712         0.03491
# White              0.939225               1.0         0.73407         0.72558
# Other              0.000000               0.0         0.00000         0.00027
# Uncoded            4.198856            9999.0         0.00000         0.00000
#
# Method    Top-4 Sampling  Top-5 Sampling  Aggregate Posterior Matching  \
# Race
# AIAN             0.01517         0.01558                       0.01716
# API              0.01802         0.01821                       0.01868
# Black            0.21056         0.20868                       0.20903
# Hispanic         0.03743         0.03842                       0.03744
# White            0.71657         0.71422                       0.71257
# Other            0.00225         0.00489                       0.00512
# Uncoded          0.00000         0.00000                       0.00000
#
# Method    True Population Matching  Data-Driven Threshold  Aggregate Posterior
# Race
# AIAN                        0.0088                0.01736             0.017150
# API                         0.0101                0.01737             0.018689
# Black                       0.2170                0.21618             0.209028
# Hispanic                    0.0237                0.03156             0.037424
# White                       0.7252                0.71636             0.712575
# Other                       0.0152                0.00117             0.005134
# Uncoded                     0.0000                0.00000             0.000000
#
# [7 rows x 22 columns]

# %%
## True Bias
if TRUE_LABEL_COL is not None:
    true_bias_table = population_fraction_table - population_fraction_table[TRUE_LABEL_COL].to_numpy()[:, np.newaxis]
else:
    true_bias_table = "Only Calculable with Ground Truth Labels Available"
true_bias_table
# Out:
# Method    self_reported   Argmax  Thompson Sampling  Threshold at 0.5  \
# Race
# AIAN                0.0  0.00362            0.00841         -0.000291
# API                 0.0  0.00263            0.00902          0.002362
# Black               0.0 -0.08928           -0.00877         -0.098666
# Hispanic            0.0  0.00414            0.01391          0.004705
# White               0.0  0.09405           -0.01223          0.107050
# Other               0.0 -0.01516           -0.01034         -0.015160
# Uncoded             0.0  0.00000            0.00000          0.035100
#
# Method    Threshold at 0.55  Threshold at 0.6  Threshold at 0.65  \
# Race
# AIAN              -0.001714         -0.002613          -0.002628
# API                0.002897          0.003510           0.004578
# Black             -0.121252         -0.143886          -0.160266
# Hispanic           0.006603          0.008925           0.011087
# White              0.128626          0.149223           0.162388
# Other             -0.015160         -0.015160          -0.015160
# Uncoded            0.122561          0.224335           0.337435
#
# Method    Threshold at 0.7  Threshold at 0.75  Threshold at 0.8  ...  \
# Race                                                             ...
# AIAN             -0.002546          -0.002361         -0.001768  ...
# API               0.005302           0.006863          0.008643  ...
# Black            -0.173831          -0.185887         -0.192773  ...
# Hispanic          0.013328           0.015429          0.016516  ...
# White             0.172906           0.181115          0.184541  ...
# Other            -0.015160          -0.015160         -0.015160  ...
# Uncoded           0.476233           0.656205          0.885547  ...
#
# Method    Threshold at 0.95  Threshold at 1.0  Top-2 Sampling  Top-3 Sampling  \
# Race
# AIAN               0.001942          -0.00882         0.00305         0.00446
# API                0.026312          -0.01008         0.00338         0.00501
# Black             -0.206642          -0.21704        -0.00356        -0.00617
# Hispanic          -0.020517          -0.02374         0.00338         0.01117
# White              0.214065           0.27484         0.00891         0.00042
# Other             -0.015160          -0.01516        -0.01516        -0.01489
# Uncoded            4.198856        9999.00000         0.00000         0.00000
#
# Method    Top-4 Sampling  Top-5 Sampling  Aggregate Posterior Matching  \
# Race
# AIAN             0.00635         0.00676                       0.00834
# API              0.00794         0.00813                       0.00860
# Black           -0.00648        -0.00836                      -0.00801
# Hispanic         0.01369         0.01468                       0.01370
# White           -0.00859        -0.01094                      -0.01259
# Other           -0.01291        -0.01027                      -0.01004
# Uncoded          0.00000         0.00000                       0.00000
#
# Method    True Population Matching  Data-Driven Threshold  Aggregate Posterior
# Race
# AIAN                      -0.00002                0.00854             0.008330
# API                        0.00002                0.00729             0.008609
# Black                     -0.00004               -0.00086            -0.008012
# Hispanic                  -0.00004                0.00782             0.013684
# White                      0.00004               -0.00880            -0.012585
# Other                      0.00004               -0.01399            -0.010026
# Uncoded                    0.00000                0.00000             0.000000
#
# [7 rows x 22 columns]

# %%
## expected bias

ap_bias_table = population_fraction_table - population_fraction_table["Aggregate Posterior"].to_numpy()[:, np.newaxis]
ap_bias_table
# Out:
# Method    self_reported    Argmax  Thompson Sampling  Threshold at 0.5  \
# Race
# AIAN          -0.008330 -0.004710           0.000080         -0.008621
# API           -0.008609 -0.005979           0.000411         -0.006247
# Black          0.008012 -0.081268          -0.000758         -0.090654
# Hispanic      -0.013684 -0.009544           0.000226         -0.008979
# White          0.012585  0.106635           0.000355          0.119635
# Other          0.010026 -0.005134          -0.000314         -0.005134
# Uncoded        0.000000  0.000000           0.000000          0.035100
#
# Method    Threshold at 0.55  Threshold at 0.6  Threshold at 0.65  \
# Race
# AIAN              -0.010044         -0.010942          -0.010958
# API               -0.005712         -0.005099          -0.004031
# Black             -0.113240         -0.135874          -0.152254
# Hispanic          -0.007081         -0.004759          -0.002597
# White              0.141212          0.161808           0.174974
# Other             -0.005134         -0.005134          -0.005134
# Uncoded            0.122561          0.224335           0.337435
#
# Method    Threshold at 0.7  Threshold at 0.75  Threshold at 0.8  ...  \
# Race                                                             ...
# AIAN             -0.010876          -0.010691         -0.010098  ...
# API              -0.003307          -0.001746          0.000034  ...
# Black            -0.165819          -0.177875         -0.184761  ...
# Hispanic         -0.000356           0.001745          0.002832  ...
# White             0.185491           0.193701          0.197126  ...
# Other            -0.005134          -0.005134         -0.005134  ...
# Uncoded           0.476233           0.656205          0.885547  ...
#
# Method    Threshold at 0.95  Threshold at 1.0  Top-2 Sampling  Top-3 Sampling  \
# Race
# AIAN              -0.006388         -0.017150       -0.005280       -0.003870
# API                0.017703         -0.018689       -0.005229       -0.003599
# Black             -0.198630         -0.209028        0.004452        0.001842
# Hispanic          -0.034201         -0.037424       -0.010304       -0.002514
# White              0.226651          0.287425        0.021495        0.013005
# Other             -0.005134         -0.005134       -0.005134       -0.004864
# Uncoded            4.198856       9999.000000        0.000000        0.000000
#
# Method    Top-4 Sampling  Top-5 Sampling  Aggregate Posterior Matching  \
# Race
# AIAN           -0.001980       -0.001570                      0.000010
# API            -0.000669       -0.000479                     -0.000009
# Black           0.001532       -0.000348                      0.000002
# Hispanic        0.000006        0.000996                      0.000016
# White           0.003995        0.001645                     -0.000005
# Other          -0.002884       -0.000244                     -0.000014
# Uncoded         0.000000        0.000000                      0.000000
#
# Method    True Population Matching  Data-Driven Threshold  Aggregate Posterior
# Race
# AIAN                     -0.008350               0.000210                  0.0
# API                      -0.008589              -0.001319                  0.0
# Black                     0.007972               0.007152                  0.0
# Hispanic                 -0.013724              -0.005864                  0.0
# White                     0.012625               0.003785                  0.0
# Other                     0.010066              -0.003964                  0.0
# Uncoded                   0.000000               0.000000                  0.0
#
# [7 rows x 22 columns]

# %% [markdown]
# #### Error Rates

# %%
## Error Rates: False Positives and False Negatives

# Only calculable with true labels available
if TRUE_LABEL_COL is not None:
    error_table = calculate_error_rates(
        predictions,
        true_label_col=TRUE_LABEL_COL,
        uncoded_val=UNCODED_VAL,
        class_map=CLASS_NAMES,
    )
else:
    error_table = "Only Calculable with Ground Truth Labels Available"
error_table
# Out:
# Method                     Argmax  Thompson Sampling  Threshold at 0.5  \
# Race     Error Type
# White    False Positive  0.557452           0.489230          0.567670
#          False Negative  0.081582           0.202286          0.072332
# Black    False Positive  0.064013           0.151809          0.057165
#          False Negative  0.642278           0.588048          0.648799
# AIAN     False Positive  0.006971           0.012823          0.003662
#          False Negative  0.373016           0.487528          0.380079
# Hispanic False Positive  0.011216           0.023416          0.011307
#          False Negative  0.286858           0.377001          0.277181
# Other    False Positive  0.000000           0.004833          0.000000
#          False Negative  1.000000           0.996042          1.000000
# API      False Positive  0.005384           0.012183          0.005019
#          False Negative  0.267857           0.301587          0.259487
#
# Method                   Threshold at 0.55  Threshold at 0.6  \
# Race     Error Type
# White    False Positive           0.571311          0.577430
#          False Negative           0.054461          0.039987
# Black    False Positive           0.040724          0.026931
#          False Negative           0.664119          0.690355
# AIAN     False Positive           0.002375          0.001480
#          False Negative           0.372404          0.352843
# Hispanic False Positive           0.011945          0.012781
#          False Negative           0.264459          0.244627
# Other    False Positive           0.000000          0.000000
#          False Negative           1.000000          1.000000
# API      False Positive           0.005071          0.005150
#          False Negative           0.245745          0.228889
#
# Method                   Threshold at 0.65  Threshold at 0.7  \
# Race     Error Type
# White    False Positive           0.570550          0.554952
#          False Negative           0.030984          0.024208
# Black    False Positive           0.017866          0.011439
#          False Negative           0.708384          0.723556
# AIAN     False Positive           0.001132          0.001011
#          False Negative           0.310909          0.293069
# Hispanic False Positive           0.013417          0.014072
#          False Negative           0.225392          0.208978
# Other    False Positive           0.000000          0.000000
#          False Negative           1.000000          1.000000
# API      False Positive           0.005468          0.005397
#          False Negative           0.214529          0.198824
#
# Method                   Threshold at 0.75  Threshold at 0.8  \
# Race     Error Type
# White    False Positive           0.525801          0.477442
#          False Negative           0.018907          0.015741
# Black    False Positive           0.006398          0.003737
#          False Negative           0.737131          0.728346
# AIAN     False Positive           0.000901          0.000837
#          False Negative           0.275862          0.243119
# Hispanic False Positive           0.014697          0.014395
#          False Negative           0.193029          0.178340
# Other    False Positive           0.000000          0.000000
#          False Negative           1.000000          1.000000
# API      False Positive           0.005827          0.006335
#          False Negative           0.185542          0.160963
#
# Method                   Threshold at 0.85  Threshold at 0.9  \
# Race     Error Type
# White    False Positive           0.419443          0.375827
#          False Negative           0.012904          0.007884
# Black    False Positive           0.002172          0.001160
#          False Negative           0.690784          0.637731
# AIAN     False Positive           0.000657          0.000737
#          False Negative           0.237838          0.190972
# Hispanic False Positive           0.013199          0.007937
#          False Negative           0.173975          0.228743
# Other    False Positive           0.000000          0.000000
#          False Negative           1.000000          1.000000
# API      False Positive           0.007080          0.008164
#          False Negative           0.140541          0.107251
#
# Method                   Threshold at 0.95  Threshold at 1.0  Top-2 Sampling  \
# Race     Error Type
# White    False Positive           0.289407               NaN        0.510151
#          False Negative           0.002380               0.0        0.181063
# Black    False Positive           0.000478               0.0        0.155653
#          False Negative           0.513995               NaN        0.577912
# AIAN     False Positive           0.000842               0.0        0.007022
#          False Negative           0.139640               NaN        0.443311
# Hispanic False Positive           0.000472               0.0        0.012302
#          False Negative           0.641892               NaN        0.363521
# Other    False Positive           0.000000               0.0        0.000000
#          False Negative           1.000000               NaN        1.000000
# API      False Positive           0.011383               0.0        0.006445
#          False Negative           0.068834               NaN        0.297619
#
# Method                   Top-3 Sampling  Top-4 Sampling  Top-5 Sampling  \
# Race     Error Type
# White    False Positive        0.505312        0.498727        0.496835
#          False Negative        0.190937        0.200866        0.203390
# Black    False Positive        0.154938        0.155219        0.153635
#          False Negative        0.587357        0.589799        0.592748
# AIAN     False Positive        0.008788        0.010765        0.011209
#          False Negative        0.481859        0.489796        0.493197
# Hispanic False Positive        0.020568        0.023129        0.024061
#          False Negative        0.375316        0.374473        0.371104
# Other    False Positive        0.000274        0.002244        0.004904
#          False Negative        1.000000        0.997361        0.996042
# API      False Positive        0.008142        0.011213        0.011304
#          False Negative        0.302579        0.313492        0.303571
#
# Method                   Aggregate Posterior Matching  \
# Race     Error Type
# White    False Positive                      0.384660
#          False Negative                      0.163150
# Black    False Positive                      0.122778
#          False Negative                      0.479819
# AIAN     False Positive                      0.011290
#          False Negative                      0.323129
# Hispanic False Positive                      0.020650
#          False Negative                      0.272115
# Other    False Positive                      0.005158
#          False Negative                      0.997361
# API      False Positive                      0.011142
#          False Negative                      0.241071
#
# Method                   True Population Matching  Data-Driven Threshold
# Race     Error Type
# White    False Positive                  0.400378               0.389536
#          False Negative                  0.151691               0.159772
# Black    False Positive                  0.128282               0.128104
#          False Negative                  0.462956               0.466089
# AIAN     False Positive                  0.003985               0.011461
#          False Negative                  0.450113               0.319728
# Hispanic False Positive                  0.008809               0.014709
#          False Negative                  0.363943               0.275484
# Other    False Positive                  0.014571               0.001158
#          False Negative                  0.943931               0.998021
# API      False Positive                  0.003576               0.009849
#          False Negative                  0.349206               0.244048
